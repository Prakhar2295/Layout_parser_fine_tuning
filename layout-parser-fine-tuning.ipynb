# %%
import torch
print(torch.__version__)
# Out:
# 2.1.2

# %%
# !pip install git+https://github.com/facebookresearch/detectron2.git
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-z7qmhxy2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-z7qmhxy2
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 3ff5dd1cff4417af07097064813c9f28d7461d3c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (3.7.4)
# Collecting pycocotools>=2.0.2 (from detectron2==0.6)
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: termcolor>=1.1 in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (2.4.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (4.66.1)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (2.15.1)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
# done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.4 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.8 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-24.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (21.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.24.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.1 MB/s eta 0:00:00
# done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (1.0.0)
# Collecting packaging (from detectron2==0.6)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (4.9.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.5.2)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (69.0.3)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 22.1 MB/s eta 0:00:00
# Downloading black-24.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 47.2 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.2 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
# done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=1261534 sha256=5feac93cb1fa3fa5e896ecd17ff0f849910d5689fe269ecd22acfd8ea757875d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2udgkiaw/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
# done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=391f5b07757006e495b865ddfb8046e8e1c3072cd5c9061436ed558fcf62b6fc
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
# done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=401f2119cc53981a74bbe574b7e700a228b77b46d12fcd9d5f02fb2335fda2a9
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, packaging, omegaconf, iopath, hydra-core, black, pycocotools, fvcore, detectron2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.3.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# jupyterlab 4.0.11 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.2 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.8.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.1.1 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 omegaconf-2.3.0 packaging-23.2 pathspec-0.12.1 portalocker-2.8.2 pycocotools-2.0.7 yacs-0.1.8

# %%
import pandas as pd
import numpy as np
import pandas as pd
from tqdm import tqdm
from tqdm import tqdm_notebook as tqdm # progress bar
from datetime import datetime
import time
import matplotlib.pyplot as plt
#from pycocotools.coco import COCO
import os, json, cv2, random
import skimage.io as io
import copy
from pathlib import Path
from typing import Optional


# torch
import torch

# Albumenatations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

#from pycocotools.coco import COCO
from sklearn.model_selection import StratifiedKFold

# glob
from glob import glob
import json
# numba
import numba
from numba import jit

import warnings
warnings.filterwarnings('ignore') #Ignore "future" warnings and Data-Frame-Slicing warnings.


# detectron2
from detectron2.structures import BoxMode
from detectron2 import model_zoo
from detectron2.config import get_cfg
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.engine import DefaultPredictor, DefaultTrainer, launch
from detectron2.evaluation import COCOEvaluator
from detectron2.structures import BoxMode
from detectron2.utils.visualizer import ColorMode
from detectron2.utils.logger import setup_logger
from detectron2.utils.visualizer import Visualizer

from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_test_loader, build_detection_train_loader
from detectron2.data import detection_utils as utils


from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_test_loader, build_detection_train_loader
from detectron2.data import detection_utils as utils
import detectron2.data.transforms as T
from detectron2.evaluation import COCOEvaluator, inference_on_dataset,RotatedCOCOEvaluator

setup_logger()
# Out:
# <_Logger detectron2 (DEBUG)>

# %%
#f = open('/kaggle/input/papers-images/train/train/samples.json',)
f = open("/kaggle/input/tables-data/train.json")
thing_classes  = []
thing_classes_id = {}
data_annotations=[]
data = json.load(f)
#----Images----
data_images=data['images']
#---annotations-
for i in data['annotations']:
    annot_obj ={"id": i['id'],"image_id": i['image_id'],"category_id":i['category_id'],
          "x_min":i['bbox'][0], #left
          "y_min":i['bbox'][1], #top
          "x_max":i['bbox'][0]+i['bbox'][2], #left+width
          "y_max":i['bbox'][1]+i['bbox'][3] #top+hieght
         }
    data_annotations.append(annot_obj)
#---categories-
for i in data['categories']:
    thing_classes.append(i['name'])
    thing_classes_id[i['name']]=i['id']
f.close()
print("thing_classes=",thing_classes)
print("thing_classes_id=",thing_classes_id)
# Out:
# thing_classes= ['HIC_table', 'US_table']
# thing_classes_id= {'HIC_table': 0, 'US_table': 1}

# %%
thing_classes= ['HIC_table', 'US_table', 'None', 'None', 'None', 'None']

# %%
train_meta = pd.DataFrame(data_images)
train_meta = train_meta[['id', 'file_name', 'width', 'height']]
train_meta = train_meta.rename(columns={"id":"image_id"})
print("train_meta size=",len(train_meta))
train_meta.head(3)
# Out:
# train_meta size= 159
#    image_id          file_name  width  height
# 0         1  doc_img_us_37.jpg   2526    1785
# 1         2  doc_img_us_39.jpg   2526    1785
# 2         3  doc_img_us_67.jpg   2526    1785

# %%
train_df = pd.DataFrame(data_annotations)
print("train_df size=",len(train_df))
train_df.head(3)
# Out:
# train_df size= 163
#    id  image_id  category_id      x_min       y_min        x_max        y_max
# 0   1         1            1  28.803922  333.794118  1542.529412  1333.794118
# 1   2         2            1  30.686275  339.598039  1544.411765  1339.598039
# 2   3         3            1  32.607843  339.558824  1546.333333  1339.558824

# %%
#imgdir="/kaggle/input/papers-images/train/train"
imgdir = "/kaggle/input/tables-data"

debug=False
split_mode="valid20" # all_train Or  valid20
image_Width=640
image_Height=640

num_folds=5
Selected_fold=1 #1,2,3,4,5

# %%
def get_PL_data_dicts(
    imgdir: Path,
    _train_df: pd.DataFrame,
    _train_meta: pd.DataFrame,
    use_cache: bool = True,
    target_indices: Optional[np.ndarray] = None,
    debug: bool = False,
    data_type:str="train"

):
    if debug:
            train_meta = train_meta.iloc[:100]  # For debug...
    dataset_dicts = []
    for index, train_meta_row in tqdm(_train_meta.iterrows(), total=len(_train_meta)):
                    record = {}
                    image_id,file_name, width,height = train_meta_row.values
                    filename = str(f'{imgdir}/{file_name}')
                    record["file_name"] = filename
                    record["image_id"] = image_id
                    record["width"] = width
                    record["height"] = height
                    objs = []
                    for index2, row in _train_df.query("image_id == @image_id").iterrows():
                        class_id = row["category_id"]
                        bbox_resized = [
                            float(row["x_min"]),
                            float(row["y_min"]),
                            float(row["x_max"]),
                            float(row["y_max"]),
                        ]
                        obj = {
                            "bbox": bbox_resized,
                            "bbox_mode": BoxMode.XYXY_ABS,
                            "category_id": class_id,
                        }
                        objs.append(obj)
                    record["annotations"] = objs
                    dataset_dicts.append(record)

    if target_indices is not None:
        dataset_dicts = [dataset_dicts[i] for i in target_indices]

    return dataset_dicts

# %%
Data_Resister_training="PL_data_train";
Data_Resister_valid="PL_data_valid";

if split_mode == "all_train":
    DatasetCatalog.register(
        Data_Resister_training,
        lambda: get_PL_data_dicts(
            imgdir,
            train_df,
            train_meta,
            debug=debug,
            data_type="train"
        ),
    )
    MetadataCatalog.get(Data_Resister_training).set(thing_classes=thing_classes)


    dataset_dicts_train = DatasetCatalog.get(Data_Resister_training)
    metadata_dicts_train = MetadataCatalog.get(Data_Resister_training)


elif split_mode == "valid20":

    n_dataset = len(train_meta)
    n_train = int(n_dataset * 0.95)
    print("n_dataset", n_dataset, "n_train", n_train)
    rs = np.random.RandomState(12)
    inds = rs.permutation(n_dataset)
    train_inds, valid_inds = inds[:n_train], inds[n_train:]
    DatasetCatalog.register(
        Data_Resister_training,
        lambda: get_PL_data_dicts(
            imgdir,
            train_df,
            train_meta,
            target_indices=train_inds,
            debug=debug,
            data_type="train"
        ),
    )
    MetadataCatalog.get(Data_Resister_training).set(thing_classes=thing_classes)


    DatasetCatalog.register(
        Data_Resister_valid,
        lambda: get_PL_data_dicts(
            imgdir,
            train_df,
            train_meta,
            target_indices=valid_inds,
            debug=debug,
            data_type="val"
            ),
        )
    MetadataCatalog.get(Data_Resister_valid).set(thing_classes=thing_classes)

    dataset_dicts_train = DatasetCatalog.get(Data_Resister_training)
    metadata_dicts_train = MetadataCatalog.get(Data_Resister_training)

    dataset_dicts_valid = DatasetCatalog.get(Data_Resister_valid)
    metadata_dicts_valid = MetadataCatalog.get(Data_Resister_valid)

else:
    raise ValueError(f"[ERROR] Unexpected value split_mode={split_mode}")
# Out:
# n_dataset 159 n_train 151
#   0%|          | 0/159 [00:00<?, ?it/s]
#   0%|          | 0/159 [00:00<?, ?it/s]

# %%
print("dicts training size=",len(dataset_dicts_train),"################  dicts valid size=",len(dataset_dicts_valid))
# Out:
# dicts training size= 151 ################  dicts valid size= 8

# %%
from detectron2.engine import DefaultTrainer

# %%
cfg = get_cfg()
config_name = "COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"

cfg.merge_from_file(model_zoo.get_config_file(config_name))

cfg.DATASETS.TRAIN = (Data_Resister_training,)

if split_mode == "all_train":
    cfg.DATASETS.TEST = ()
else:
    cfg.DATASETS.TEST = (Data_Resister_valid,)
    cfg.TEST.EVAL_PERIOD = 1000

cfg.DATALOADER.NUM_WORKERS = 0
#cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(config_name)
cfg.MODEL.WEIGHTS="/kaggle/input/layout-parser-weights/Weights/faster_rcnn_R_50_FPN_3x/model_final.pth"

cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.0025

cfg.SOLVER.WARMUP_ITERS = 10
cfg.SOLVER.MAX_ITER = 2000 #adjust up if val mAP is still rising, adjust down if overfit
cfg.SOLVER.STEPS = (500, 1000) # must be less than  MAX_ITER
cfg.SOLVER.GAMMA = 0.05


cfg.SOLVER.CHECKPOINT_PERIOD = 100000  # Small value=Frequent save need a lot of storage.
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 4
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 6


os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)


#Training using custom trainer defined above
#trainer = AugTrainer(cfg)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/10 15:53:24 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=7, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )
#   0%|          | 0/159 [00:00<?, ?it/s]
# [02/10 15:53:25 d2.data.build]: Removed 0 images with no usable annotations. 151 images left.
# [02/10 15:53:25 d2.data.build]: Distribution of instances among all 6 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# | HIC_table  | 76           |  US_table  | 79           |    None    | 0            |
# |    None    | 0            |    None    | 0            |    None    | 0            |
# |            |              |            |              |            |              |
# |   total    | 155          |            |              |            |              |
# [02/10 15:53:25 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/10 15:53:25 d2.data.build]: Using training sampler TrainingSampler
# [02/10 15:53:25 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/10 15:53:25 d2.data.common]: Serializing 151 elements to byte tensors and concatenating them all ...
# [02/10 15:53:25 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/10 15:53:25 d2.data.build]: Making batched data loader with batch_size=4
# [02/10 15:53:25 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /kaggle/input/layout-parser-weights/Weights/faster_rcnn_R_50_FPN_3x/model_final.pth ...
# [02/10 15:53:28 d2.engine.train_loop]: Starting training from iteration 0
# [02/10 15:53:54 d2.utils.events]:  eta: 0:38:18  iter: 19  total_loss: 1.026  loss_cls: 0.2896  loss_box_reg: 0.6404  loss_rpn_cls: 0.01233  loss_rpn_loc: 0.007229    time: 1.1591  last_time: 1.1087  data_time: 0.7369  last_data_time: 0.7143   lr: 0.0025  max_mem: 4229M
# 2024-02-10 15:53:56.441515: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-10 15:53:56.441626: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-10 15:53:56.557337: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [02/10 15:54:28 d2.utils.events]:  eta: 0:37:52  iter: 39  total_loss: 0.6834  loss_cls: 0.07243  loss_box_reg: 0.5375  loss_rpn_cls: 0.001868  loss_rpn_loc: 0.005884    time: 1.1558  last_time: 1.1608  data_time: 0.7267  last_data_time: 0.7111   lr: 0.0025  max_mem: 4230M
# [02/10 15:54:50 d2.utils.events]:  eta: 0:37:14  iter: 59  total_loss: 0.6018  loss_cls: 0.1301  loss_box_reg: 0.4877  loss_rpn_cls: 0.003623  loss_rpn_loc: 0.005056    time: 1.1461  last_time: 1.1514  data_time: 0.7053  last_data_time: 0.7392   lr: 0.0025  max_mem: 4230M
# [02/10 15:55:13 d2.utils.events]:  eta: 0:36:36  iter: 79  total_loss: 0.5412  loss_cls: 0.08911  loss_box_reg: 0.4157  loss_rpn_cls: 0.004692  loss_rpn_loc: 0.004041    time: 1.1402  last_time: 1.1208  data_time: 0.6997  last_data_time: 0.7085   lr: 0.0025  max_mem: 4230M
# [02/10 15:55:35 d2.utils.events]:  eta: 0:36:11  iter: 99  total_loss: 0.4516  loss_cls: 0.04111  loss_box_reg: 0.3842  loss_rpn_cls: 0.005198  loss_rpn_loc: 0.004272    time: 1.1372  last_time: 1.1039  data_time: 0.7004  last_data_time: 0.6944   lr: 0.0025  max_mem: 4230M
# [02/10 15:55:58 d2.utils.events]:  eta: 0:35:38  iter: 119  total_loss: 0.4552  loss_cls: 0.05506  loss_box_reg: 0.3859  loss_rpn_cls: 0.003121  loss_rpn_loc: 0.003708    time: 1.1348  last_time: 1.1323  data_time: 0.6930  last_data_time: 0.6837   lr: 0.0025  max_mem: 4230M
# [02/10 15:56:20 d2.utils.events]:  eta: 0:35:15  iter: 139  total_loss: 0.4081  loss_cls: 0.05661  loss_box_reg: 0.3405  loss_rpn_cls: 0.001984  loss_rpn_loc: 0.003176    time: 1.1337  last_time: 1.1417  data_time: 0.7079  last_data_time: 0.6921   lr: 0.0025  max_mem: 4230M
# [02/10 15:56:43 d2.utils.events]:  eta: 0:34:52  iter: 159  total_loss: 0.4674  loss_cls: 0.06183  loss_box_reg: 0.3642  loss_rpn_cls: 0.003948  loss_rpn_loc: 0.005084    time: 1.1333  last_time: 1.1575  data_time: 0.7066  last_data_time: 0.7075   lr: 0.0025  max_mem: 4230M
# [02/10 15:57:06 d2.utils.events]:  eta: 0:34:31  iter: 179  total_loss: 0.3594  loss_cls: 0.02925  loss_box_reg: 0.3242  loss_rpn_cls: 0.002706  loss_rpn_loc: 0.003267    time: 1.1343  last_time: 1.1879  data_time: 0.7093  last_data_time: 0.7326   lr: 0.0025  max_mem: 4230M
# [02/10 15:57:28 d2.utils.events]:  eta: 0:34:09  iter: 199  total_loss: 0.4111  loss_cls: 0.04816  loss_box_reg: 0.3503  loss_rpn_cls: 0.00176  loss_rpn_loc: 0.003408    time: 1.1344  last_time: 1.1550  data_time: 0.7070  last_data_time: 0.7030   lr: 0.0025  max_mem: 4230M
# [02/10 15:57:51 d2.utils.events]:  eta: 0:33:49  iter: 219  total_loss: 0.3561  loss_cls: 0.02015  loss_box_reg: 0.3271  loss_rpn_cls: 0.003508  loss_rpn_loc: 0.003188    time: 1.1342  last_time: 1.1294  data_time: 0.7057  last_data_time: 0.7147   lr: 0.0025  max_mem: 4230M
# [02/10 15:58:14 d2.utils.events]:  eta: 0:33:26  iter: 239  total_loss: 0.4183  loss_cls: 0.03007  loss_box_reg: 0.3039  loss_rpn_cls: 0.001996  loss_rpn_loc: 0.002733    time: 1.1339  last_time: 1.0537  data_time: 0.7109  last_data_time: 0.6921   lr: 0.0025  max_mem: 4230M
# [02/10 15:58:36 d2.utils.events]:  eta: 0:33:05  iter: 259  total_loss: 0.3032  loss_cls: 0.03364  loss_box_reg: 0.2514  loss_rpn_cls: 0.002179  loss_rpn_loc: 0.003506    time: 1.1344  last_time: 1.1176  data_time: 0.7041  last_data_time: 0.7058   lr: 0.0025  max_mem: 4230M
# [02/10 15:58:59 d2.utils.events]:  eta: 0:32:41  iter: 279  total_loss: 0.284  loss_cls: 0.01228  loss_box_reg: 0.231  loss_rpn_cls: 0.003289  loss_rpn_loc: 0.003167    time: 1.1342  last_time: 1.1598  data_time: 0.7152  last_data_time: 0.7114   lr: 0.0025  max_mem: 4230M
# [02/10 15:59:22 d2.utils.events]:  eta: 0:32:18  iter: 299  total_loss: 0.3985  loss_cls: 0.0617  loss_box_reg: 0.2998  loss_rpn_cls: 0.004368  loss_rpn_loc: 0.004054    time: 1.1340  last_time: 1.1762  data_time: 0.7067  last_data_time: 0.7130   lr: 0.0025  max_mem: 4230M
# [02/10 15:59:44 d2.utils.events]:  eta: 0:31:56  iter: 319  total_loss: 0.3403  loss_cls: 0.01639  loss_box_reg: 0.2857  loss_rpn_cls: 0.001595  loss_rpn_loc: 0.002945    time: 1.1341  last_time: 1.0654  data_time: 0.7052  last_data_time: 0.6996   lr: 0.0025  max_mem: 4230M
# [02/10 16:00:07 d2.utils.events]:  eta: 0:31:36  iter: 339  total_loss: 0.3036  loss_cls: 0.03611  loss_box_reg: 0.2482  loss_rpn_cls: 0.001246  loss_rpn_loc: 0.002932    time: 1.1349  last_time: 1.1602  data_time: 0.7116  last_data_time: 0.7069   lr: 0.0025  max_mem: 4230M
# [02/10 16:00:30 d2.utils.events]:  eta: 0:31:13  iter: 359  total_loss: 0.2775  loss_cls: 0.01661  loss_box_reg: 0.251  loss_rpn_cls: 0.002154  loss_rpn_loc: 0.00288    time: 1.1357  last_time: 1.0882  data_time: 0.7212  last_data_time: 0.7239   lr: 0.0025  max_mem: 4230M
# [02/10 16:00:53 d2.utils.events]:  eta: 0:30:50  iter: 379  total_loss: 0.2857  loss_cls: 0.02116  loss_box_reg: 0.2505  loss_rpn_cls: 0.002025  loss_rpn_loc: 0.003697    time: 1.1361  last_time: 1.1855  data_time: 0.7171  last_data_time: 0.7333   lr: 0.0025  max_mem: 4230M
# [02/10 16:01:16 d2.utils.events]:  eta: 0:30:28  iter: 399  total_loss: 0.289  loss_cls: 0.01981  loss_box_reg: 0.2514  loss_rpn_cls: 0.002008  loss_rpn_loc: 0.002622    time: 1.1370  last_time: 1.1359  data_time: 0.7201  last_data_time: 0.7262   lr: 0.0025  max_mem: 4230M
# [02/10 16:01:39 d2.utils.events]:  eta: 0:30:04  iter: 419  total_loss: 0.2603  loss_cls: 0.02081  loss_box_reg: 0.2113  loss_rpn_cls: 0.001698  loss_rpn_loc: 0.002802    time: 1.1370  last_time: 1.1729  data_time: 0.7132  last_data_time: 0.7180   lr: 0.0025  max_mem: 4230M
# [02/10 16:02:02 d2.utils.events]:  eta: 0:29:41  iter: 439  total_loss: 0.2554  loss_cls: 0.01891  loss_box_reg: 0.2186  loss_rpn_cls: 0.002324  loss_rpn_loc: 0.003683    time: 1.1371  last_time: 1.1325  data_time: 0.7114  last_data_time: 0.7187   lr: 0.0025  max_mem: 4230M
# [02/10 16:02:25 d2.utils.events]:  eta: 0:29:19  iter: 459  total_loss: 0.3206  loss_cls: 0.015  loss_box_reg: 0.2813  loss_rpn_cls: 0.002329  loss_rpn_loc: 0.002709    time: 1.1372  last_time: 1.1166  data_time: 0.7041  last_data_time: 0.7062   lr: 0.0025  max_mem: 4230M
# [02/10 16:02:48 d2.utils.events]:  eta: 0:28:56  iter: 479  total_loss: 0.28  loss_cls: 0.02928  loss_box_reg: 0.2243  loss_rpn_cls: 0.002516  loss_rpn_loc: 0.003125    time: 1.1374  last_time: 1.2100  data_time: 0.7154  last_data_time: 0.7597   lr: 0.0025  max_mem: 4230M
# [02/10 16:03:11 d2.utils.events]:  eta: 0:28:35  iter: 499  total_loss: 0.3553  loss_cls: 0.04755  loss_box_reg: 0.2889  loss_rpn_cls: 0.001528  loss_rpn_loc: 0.002903    time: 1.1379  last_time: 1.1331  data_time: 0.7222  last_data_time: 0.7361   lr: 0.0025  max_mem: 4230M
# [02/10 16:03:33 d2.utils.events]:  eta: 0:28:13  iter: 519  total_loss: 0.2856  loss_cls: 0.01405  loss_box_reg: 0.2416  loss_rpn_cls: 0.00277  loss_rpn_loc: 0.002506    time: 1.1381  last_time: 1.1447  data_time: 0.7151  last_data_time: 0.6927   lr: 0.000125  max_mem: 4230M
# [02/10 16:03:56 d2.utils.events]:  eta: 0:27:49  iter: 539  total_loss: 0.2126  loss_cls: 0.02843  loss_box_reg: 0.1765  loss_rpn_cls: 0.002853  loss_rpn_loc: 0.002446    time: 1.1382  last_time: 1.1107  data_time: 0.7143  last_data_time: 0.6991   lr: 0.000125  max_mem: 4230M
# [02/10 16:04:19 d2.utils.events]:  eta: 0:27:27  iter: 559  total_loss: 0.2038  loss_cls: 0.01723  loss_box_reg: 0.177  loss_rpn_cls: 0.002145  loss_rpn_loc: 0.0024    time: 1.1384  last_time: 1.1902  data_time: 0.7067  last_data_time: 0.7392   lr: 0.000125  max_mem: 4230M
# [02/10 16:04:42 d2.utils.events]:  eta: 0:27:03  iter: 579  total_loss: 0.2001  loss_cls: 0.01785  loss_box_reg: 0.1759  loss_rpn_cls: 0.001895  loss_rpn_loc: 0.002326    time: 1.1383  last_time: 1.1813  data_time: 0.7083  last_data_time: 0.7293   lr: 0.000125  max_mem: 4230M
# [02/10 16:05:05 d2.utils.events]:  eta: 0:26:40  iter: 599  total_loss: 0.1622  loss_cls: 0.01289  loss_box_reg: 0.1397  loss_rpn_cls: 0.002842  loss_rpn_loc: 0.002942    time: 1.1383  last_time: 1.1417  data_time: 0.7070  last_data_time: 0.6910   lr: 0.000125  max_mem: 4230M
# [02/10 16:05:27 d2.utils.events]:  eta: 0:26:17  iter: 619  total_loss: 0.1608  loss_cls: 0.01371  loss_box_reg: 0.1297  loss_rpn_cls: 0.002261  loss_rpn_loc: 0.002283    time: 1.1382  last_time: 1.1115  data_time: 0.7039  last_data_time: 0.7035   lr: 0.000125  max_mem: 4230M
# [02/10 16:05:50 d2.utils.events]:  eta: 0:25:55  iter: 639  total_loss: 0.1308  loss_cls: 0.01096  loss_box_reg: 0.1033  loss_rpn_cls: 0.002072  loss_rpn_loc: 0.002504    time: 1.1385  last_time: 1.1284  data_time: 0.7130  last_data_time: 0.7137   lr: 0.000125  max_mem: 4230M
# [02/10 16:06:13 d2.utils.events]:  eta: 0:25:32  iter: 659  total_loss: 0.1354  loss_cls: 0.01326  loss_box_reg: 0.1071  loss_rpn_cls: 0.00253  loss_rpn_loc: 0.002573    time: 1.1384  last_time: 1.1074  data_time: 0.7055  last_data_time: 0.7093   lr: 0.000125  max_mem: 4230M
# [02/10 16:06:36 d2.utils.events]:  eta: 0:25:08  iter: 679  total_loss: 0.1362  loss_cls: 0.008831  loss_box_reg: 0.1164  loss_rpn_cls: 0.002242  loss_rpn_loc: 0.002151    time: 1.1382  last_time: 1.1098  data_time: 0.7102  last_data_time: 0.6934   lr: 0.000125  max_mem: 4230M
# [02/10 16:06:58 d2.utils.events]:  eta: 0:24:46  iter: 699  total_loss: 0.1314  loss_cls: 0.01428  loss_box_reg: 0.1052  loss_rpn_cls: 0.001853  loss_rpn_loc: 0.002208    time: 1.1382  last_time: 1.1561  data_time: 0.7104  last_data_time: 0.7048   lr: 0.000125  max_mem: 4230M
# [02/10 16:07:21 d2.utils.events]:  eta: 0:24:23  iter: 719  total_loss: 0.1523  loss_cls: 0.01757  loss_box_reg: 0.1226  loss_rpn_cls: 0.001945  loss_rpn_loc: 0.002125    time: 1.1382  last_time: 1.0961  data_time: 0.7093  last_data_time: 0.7008   lr: 0.000125  max_mem: 4230M
# [02/10 16:07:44 d2.utils.events]:  eta: 0:24:00  iter: 739  total_loss: 0.1441  loss_cls: 0.014  loss_box_reg: 0.1035  loss_rpn_cls: 0.002275  loss_rpn_loc: 0.002366    time: 1.1380  last_time: 1.1496  data_time: 0.7085  last_data_time: 0.6967   lr: 0.000125  max_mem: 4231M
# [02/10 16:08:07 d2.utils.events]:  eta: 0:23:38  iter: 759  total_loss: 0.1243  loss_cls: 0.01411  loss_box_reg: 0.09387  loss_rpn_cls: 0.001914  loss_rpn_loc: 0.002034    time: 1.1381  last_time: 1.1545  data_time: 0.7112  last_data_time: 0.7019   lr: 0.000125  max_mem: 4231M
# [02/10 16:08:29 d2.utils.events]:  eta: 0:23:15  iter: 779  total_loss: 0.1375  loss_cls: 0.01197  loss_box_reg: 0.1219  loss_rpn_cls: 0.002364  loss_rpn_loc: 0.002258    time: 1.1380  last_time: 1.1494  data_time: 0.7067  last_data_time: 0.6949   lr: 0.000125  max_mem: 4231M
# [02/10 16:08:52 d2.utils.events]:  eta: 0:22:52  iter: 799  total_loss: 0.1249  loss_cls: 0.01619  loss_box_reg: 0.1072  loss_rpn_cls: 0.00203  loss_rpn_loc: 0.002108    time: 1.1382  last_time: 1.2019  data_time: 0.7125  last_data_time: 0.7478   lr: 0.000125  max_mem: 4231M
# [02/10 16:09:15 d2.utils.events]:  eta: 0:22:29  iter: 819  total_loss: 0.1197  loss_cls: 0.01063  loss_box_reg: 0.1028  loss_rpn_cls: 0.002301  loss_rpn_loc: 0.002213    time: 1.1382  last_time: 1.1591  data_time: 0.7066  last_data_time: 0.7085   lr: 0.000125  max_mem: 4231M
# [02/10 16:09:38 d2.utils.events]:  eta: 0:22:07  iter: 839  total_loss: 0.1054  loss_cls: 0.01129  loss_box_reg: 0.08349  loss_rpn_cls: 0.002378  loss_rpn_loc: 0.002094    time: 1.1385  last_time: 1.1587  data_time: 0.7167  last_data_time: 0.7090   lr: 0.000125  max_mem: 4231M
# [02/10 16:10:01 d2.utils.events]:  eta: 0:21:45  iter: 859  total_loss: 0.09665  loss_cls: 0.008076  loss_box_reg: 0.08301  loss_rpn_cls: 0.001975  loss_rpn_loc: 0.002292    time: 1.1386  last_time: 1.1656  data_time: 0.7112  last_data_time: 0.7114   lr: 0.000125  max_mem: 4231M
# [02/10 16:10:24 d2.utils.events]:  eta: 0:21:22  iter: 879  total_loss: 0.1123  loss_cls: 0.009164  loss_box_reg: 0.0873  loss_rpn_cls: 0.001731  loss_rpn_loc: 0.002005    time: 1.1388  last_time: 1.1213  data_time: 0.7149  last_data_time: 0.7080   lr: 0.000125  max_mem: 4231M
# [02/10 16:10:47 d2.utils.events]:  eta: 0:21:00  iter: 899  total_loss: 0.1117  loss_cls: 0.01204  loss_box_reg: 0.09472  loss_rpn_cls: 0.002208  loss_rpn_loc: 0.002255    time: 1.1391  last_time: 1.1850  data_time: 0.7168  last_data_time: 0.7310   lr: 0.000125  max_mem: 4231M
# [02/10 16:11:10 d2.utils.events]:  eta: 0:20:36  iter: 919  total_loss: 0.1052  loss_cls: 0.01544  loss_box_reg: 0.0806  loss_rpn_cls: 0.00224  loss_rpn_loc: 0.002221    time: 1.1390  last_time: 1.1665  data_time: 0.7121  last_data_time: 0.7160   lr: 0.000125  max_mem: 4231M
# [02/10 16:11:33 d2.utils.events]:  eta: 0:20:14  iter: 939  total_loss: 0.1023  loss_cls: 0.009932  loss_box_reg: 0.08246  loss_rpn_cls: 0.001938  loss_rpn_loc: 0.002051    time: 1.1391  last_time: 1.1336  data_time: 0.7055  last_data_time: 0.7380   lr: 0.000125  max_mem: 4231M
# [02/10 16:11:55 d2.utils.events]:  eta: 0:19:51  iter: 959  total_loss: 0.1016  loss_cls: 0.01516  loss_box_reg: 0.07578  loss_rpn_cls: 0.002208  loss_rpn_loc: 0.002158    time: 1.1389  last_time: 1.1409  data_time: 0.7048  last_data_time: 0.6885   lr: 0.000125  max_mem: 4231M
# [02/10 16:12:18 d2.utils.events]:  eta: 0:19:28  iter: 979  total_loss: 0.1149  loss_cls: 0.01376  loss_box_reg: 0.09285  loss_rpn_cls: 0.002227  loss_rpn_loc: 0.002087    time: 1.1389  last_time: 1.1069  data_time: 0.7081  last_data_time: 0.6956   lr: 0.000125  max_mem: 4231M
#   0%|          | 0/159 [00:00<?, ?it/s]
# [02/10 16:12:42 d2.data.build]: Distribution of instances among all 6 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# | HIC_table  | 3            |  US_table  | 5            |    None    | 0            |
# |    None    | 0            |    None    | 0            |    None    | 0            |
# |            |              |            |              |            |              |
# |   total    | 8            |            |              |            |              |
# [02/10 16:12:42 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/10 16:12:42 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/10 16:12:42 d2.data.common]: Serializing 8 elements to byte tensors and concatenating them all ...
# [02/10 16:12:42 d2.data.common]: Serialized dataset takes 0.00 MiB
# WARNING [02/10 16:12:42 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [02/10 16:12:42 d2.utils.events]:  eta: 0:19:05  iter: 999  total_loss: 0.1052  loss_cls: 0.01071  loss_box_reg: 0.07502  loss_rpn_cls: 0.002307  loss_rpn_loc: 0.002052    time: 1.1392  last_time: 1.1211  data_time: 0.7125  last_data_time: 0.7086   lr: 0.000125  max_mem: 4231M
# [02/10 16:13:05 d2.utils.events]:  eta: 0:18:42  iter: 1019  total_loss: 0.09305  loss_cls: 0.008606  loss_box_reg: 0.08184  loss_rpn_cls: 0.001823  loss_rpn_loc: 0.001944    time: 1.1398  last_time: 1.1926  data_time: 0.7342  last_data_time: 0.7398   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:13:28 d2.utils.events]:  eta: 0:18:19  iter: 1039  total_loss: 0.09806  loss_cls: 0.01017  loss_box_reg: 0.0743  loss_rpn_cls: 0.002011  loss_rpn_loc: 0.002206    time: 1.1399  last_time: 1.1471  data_time: 0.7123  last_data_time: 0.6946   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:13:51 d2.utils.events]:  eta: 0:17:57  iter: 1059  total_loss: 0.1053  loss_cls: 0.01195  loss_box_reg: 0.07426  loss_rpn_cls: 0.002033  loss_rpn_loc: 0.001997    time: 1.1400  last_time: 1.1171  data_time: 0.7098  last_data_time: 0.7065   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:14:13 d2.utils.events]:  eta: 0:17:34  iter: 1079  total_loss: 0.08702  loss_cls: 0.008319  loss_box_reg: 0.06758  loss_rpn_cls: 0.00198  loss_rpn_loc: 0.002452    time: 1.1399  last_time: 1.1713  data_time: 0.7106  last_data_time: 0.7178   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:14:36 d2.utils.events]:  eta: 0:17:11  iter: 1099  total_loss: 0.1139  loss_cls: 0.01895  loss_box_reg: 0.07474  loss_rpn_cls: 0.001625  loss_rpn_loc: 0.001725    time: 1.1397  last_time: 1.0708  data_time: 0.7077  last_data_time: 0.7092   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:14:59 d2.utils.events]:  eta: 0:16:49  iter: 1119  total_loss: 0.07931  loss_cls: 0.009017  loss_box_reg: 0.06789  loss_rpn_cls: 0.002059  loss_rpn_loc: 0.00204    time: 1.1397  last_time: 1.1496  data_time: 0.7070  last_data_time: 0.6996   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:15:22 d2.utils.events]:  eta: 0:16:26  iter: 1139  total_loss: 0.08605  loss_cls: 0.007786  loss_box_reg: 0.06153  loss_rpn_cls: 0.002094  loss_rpn_loc: 0.002064    time: 1.1398  last_time: 1.1065  data_time: 0.7166  last_data_time: 0.7112   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:15:44 d2.utils.events]:  eta: 0:16:03  iter: 1159  total_loss: 0.09341  loss_cls: 0.01223  loss_box_reg: 0.07297  loss_rpn_cls: 0.001781  loss_rpn_loc: 0.001785    time: 1.1397  last_time: 1.1054  data_time: 0.7128  last_data_time: 0.6942   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:16:07 d2.utils.events]:  eta: 0:15:40  iter: 1179  total_loss: 0.08235  loss_cls: 0.00753  loss_box_reg: 0.06871  loss_rpn_cls: 0.00223  loss_rpn_loc: 0.001972    time: 1.1395  last_time: 1.1554  data_time: 0.7167  last_data_time: 0.7551   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:16:30 d2.utils.events]:  eta: 0:15:17  iter: 1199  total_loss: 0.07379  loss_cls: 0.009249  loss_box_reg: 0.062  loss_rpn_cls: 0.002249  loss_rpn_loc: 0.001738    time: 1.1396  last_time: 1.1304  data_time: 0.7127  last_data_time: 0.7210   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:16:53 d2.utils.events]:  eta: 0:14:54  iter: 1219  total_loss: 0.09004  loss_cls: 0.01164  loss_box_reg: 0.07349  loss_rpn_cls: 0.001866  loss_rpn_loc: 0.002124    time: 1.1397  last_time: 1.2049  data_time: 0.7202  last_data_time: 0.7493   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:17:16 d2.utils.events]:  eta: 0:14:32  iter: 1239  total_loss: 0.09308  loss_cls: 0.01037  loss_box_reg: 0.06347  loss_rpn_cls: 0.002108  loss_rpn_loc: 0.002221    time: 1.1400  last_time: 1.1236  data_time: 0.7240  last_data_time: 0.7117   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:17:39 d2.utils.events]:  eta: 0:14:09  iter: 1259  total_loss: 0.08864  loss_cls: 0.008796  loss_box_reg: 0.06448  loss_rpn_cls: 0.001904  loss_rpn_loc: 0.001874    time: 1.1401  last_time: 1.1825  data_time: 0.7181  last_data_time: 0.7693   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:18:02 d2.utils.events]:  eta: 0:13:46  iter: 1279  total_loss: 0.1107  loss_cls: 0.01613  loss_box_reg: 0.07196  loss_rpn_cls: 0.001626  loss_rpn_loc: 0.001759    time: 1.1403  last_time: 1.2349  data_time: 0.7286  last_data_time: 0.7844   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:18:25 d2.utils.events]:  eta: 0:13:23  iter: 1299  total_loss: 0.09684  loss_cls: 0.01326  loss_box_reg: 0.06958  loss_rpn_cls: 0.002516  loss_rpn_loc: 0.0021    time: 1.1404  last_time: 1.1344  data_time: 0.7164  last_data_time: 0.7192   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:18:48 d2.utils.events]:  eta: 0:13:01  iter: 1319  total_loss: 0.09449  loss_cls: 0.009015  loss_box_reg: 0.06874  loss_rpn_cls: 0.002134  loss_rpn_loc: 0.001912    time: 1.1406  last_time: 1.1713  data_time: 0.7230  last_data_time: 0.7212   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:19:11 d2.utils.events]:  eta: 0:12:37  iter: 1339  total_loss: 0.1025  loss_cls: 0.01012  loss_box_reg: 0.08551  loss_rpn_cls: 0.001718  loss_rpn_loc: 0.001849    time: 1.1405  last_time: 1.1516  data_time: 0.7201  last_data_time: 0.7421   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:19:34 d2.utils.events]:  eta: 0:12:15  iter: 1359  total_loss: 0.09369  loss_cls: 0.01038  loss_box_reg: 0.0626  loss_rpn_cls: 0.001944  loss_rpn_loc: 0.001977    time: 1.1407  last_time: 1.1156  data_time: 0.7211  last_data_time: 0.7020   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:19:57 d2.utils.events]:  eta: 0:11:52  iter: 1379  total_loss: 0.1029  loss_cls: 0.009129  loss_box_reg: 0.07238  loss_rpn_cls: 0.002146  loss_rpn_loc: 0.002017    time: 1.1408  last_time: 1.1274  data_time: 0.7286  last_data_time: 0.7154   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:20:20 d2.utils.events]:  eta: 0:11:29  iter: 1399  total_loss: 0.07416  loss_cls: 0.008055  loss_box_reg: 0.0639  loss_rpn_cls: 0.001829  loss_rpn_loc: 0.001837    time: 1.1408  last_time: 1.1673  data_time: 0.7223  last_data_time: 0.7147   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:20:43 d2.utils.events]:  eta: 0:11:06  iter: 1419  total_loss: 0.09089  loss_cls: 0.01235  loss_box_reg: 0.07026  loss_rpn_cls: 0.002475  loss_rpn_loc: 0.001633    time: 1.1411  last_time: 1.1747  data_time: 0.7263  last_data_time: 0.7229   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:21:06 d2.utils.events]:  eta: 0:10:43  iter: 1439  total_loss: 0.09028  loss_cls: 0.00919  loss_box_reg: 0.06604  loss_rpn_cls: 0.001856  loss_rpn_loc: 0.002059    time: 1.1413  last_time: 1.1663  data_time: 0.7219  last_data_time: 0.7128   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:21:29 d2.utils.events]:  eta: 0:10:21  iter: 1459  total_loss: 0.07956  loss_cls: 0.007787  loss_box_reg: 0.06579  loss_rpn_cls: 0.001948  loss_rpn_loc: 0.002115    time: 1.1415  last_time: 1.0872  data_time: 0.7323  last_data_time: 0.7231   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:21:52 d2.utils.events]:  eta: 0:09:58  iter: 1479  total_loss: 0.1111  loss_cls: 0.01019  loss_box_reg: 0.09243  loss_rpn_cls: 0.001769  loss_rpn_loc: 0.002004    time: 1.1417  last_time: 1.1625  data_time: 0.7206  last_data_time: 0.7475   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:22:15 d2.utils.events]:  eta: 0:09:35  iter: 1499  total_loss: 0.1054  loss_cls: 0.01546  loss_box_reg: 0.07286  loss_rpn_cls: 0.001446  loss_rpn_loc: 0.002079    time: 1.1417  last_time: 1.1706  data_time: 0.7114  last_data_time: 0.7184   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:22:38 d2.utils.events]:  eta: 0:09:11  iter: 1519  total_loss: 0.09629  loss_cls: 0.009241  loss_box_reg: 0.06705  loss_rpn_cls: 0.00237  loss_rpn_loc: 0.00188    time: 1.1415  last_time: 1.1115  data_time: 0.7093  last_data_time: 0.6989   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:23:01 d2.utils.events]:  eta: 0:08:48  iter: 1539  total_loss: 0.11  loss_cls: 0.00983  loss_box_reg: 0.08269  loss_rpn_cls: 0.001713  loss_rpn_loc: 0.001887    time: 1.1415  last_time: 1.1028  data_time: 0.7207  last_data_time: 0.7027   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:23:24 d2.utils.events]:  eta: 0:08:26  iter: 1559  total_loss: 0.102  loss_cls: 0.01045  loss_box_reg: 0.08313  loss_rpn_cls: 0.001892  loss_rpn_loc: 0.001835    time: 1.1416  last_time: 1.1589  data_time: 0.7152  last_data_time: 0.7090   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:23:46 d2.utils.events]:  eta: 0:08:03  iter: 1579  total_loss: 0.08124  loss_cls: 0.007961  loss_box_reg: 0.0634  loss_rpn_cls: 0.002031  loss_rpn_loc: 0.001799    time: 1.1416  last_time: 1.1289  data_time: 0.7124  last_data_time: 0.7203   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:24:09 d2.utils.events]:  eta: 0:07:40  iter: 1599  total_loss: 0.09847  loss_cls: 0.01288  loss_box_reg: 0.07256  loss_rpn_cls: 0.002261  loss_rpn_loc: 0.00246    time: 1.1416  last_time: 1.1077  data_time: 0.7106  last_data_time: 0.6912   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:24:32 d2.utils.events]:  eta: 0:07:17  iter: 1619  total_loss: 0.08005  loss_cls: 0.009311  loss_box_reg: 0.06456  loss_rpn_cls: 0.00166  loss_rpn_loc: 0.002121    time: 1.1415  last_time: 1.1157  data_time: 0.7068  last_data_time: 0.7048   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:24:55 d2.utils.events]:  eta: 0:06:53  iter: 1639  total_loss: 0.08828  loss_cls: 0.007431  loss_box_reg: 0.07072  loss_rpn_cls: 0.00172  loss_rpn_loc: 0.001888    time: 1.1414  last_time: 1.1164  data_time: 0.7109  last_data_time: 0.7048   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:25:17 d2.utils.events]:  eta: 0:06:30  iter: 1659  total_loss: 0.09326  loss_cls: 0.008927  loss_box_reg: 0.07228  loss_rpn_cls: 0.001748  loss_rpn_loc: 0.001933    time: 1.1414  last_time: 1.1748  data_time: 0.7067  last_data_time: 0.7616   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:25:40 d2.utils.events]:  eta: 0:06:08  iter: 1679  total_loss: 0.1027  loss_cls: 0.01524  loss_box_reg: 0.07772  loss_rpn_cls: 0.001759  loss_rpn_loc: 0.001856    time: 1.1412  last_time: 1.1065  data_time: 0.7104  last_data_time: 0.6984   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:26:03 d2.utils.events]:  eta: 0:05:44  iter: 1699  total_loss: 0.07727  loss_cls: 0.00954  loss_box_reg: 0.06572  loss_rpn_cls: 0.002027  loss_rpn_loc: 0.001915    time: 1.1411  last_time: 1.1274  data_time: 0.7079  last_data_time: 0.6802   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:26:26 d2.utils.events]:  eta: 0:05:22  iter: 1719  total_loss: 0.1154  loss_cls: 0.01344  loss_box_reg: 0.0733  loss_rpn_cls: 0.001527  loss_rpn_loc: 0.001865    time: 1.1412  last_time: 1.1241  data_time: 0.7125  last_data_time: 0.7133   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:26:48 d2.utils.events]:  eta: 0:04:58  iter: 1739  total_loss: 0.1087  loss_cls: 0.009164  loss_box_reg: 0.08773  loss_rpn_cls: 0.002098  loss_rpn_loc: 0.001963    time: 1.1409  last_time: 1.1076  data_time: 0.7005  last_data_time: 0.6922   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:27:11 d2.utils.events]:  eta: 0:04:35  iter: 1759  total_loss: 0.1116  loss_cls: 0.01074  loss_box_reg: 0.07899  loss_rpn_cls: 0.001555  loss_rpn_loc: 0.001931    time: 1.1408  last_time: 1.0422  data_time: 0.7096  last_data_time: 0.7082   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:27:34 d2.utils.events]:  eta: 0:04:12  iter: 1779  total_loss: 0.09321  loss_cls: 0.01073  loss_box_reg: 0.07058  loss_rpn_cls: 0.002191  loss_rpn_loc: 0.002073    time: 1.1409  last_time: 1.0914  data_time: 0.7161  last_data_time: 0.6948   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:27:56 d2.utils.events]:  eta: 0:03:49  iter: 1799  total_loss: 0.1001  loss_cls: 0.01034  loss_box_reg: 0.0774  loss_rpn_cls: 0.002407  loss_rpn_loc: 0.00225    time: 1.1408  last_time: 1.0938  data_time: 0.7086  last_data_time: 0.6977   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:28:19 d2.utils.events]:  eta: 0:03:26  iter: 1819  total_loss: 0.08804  loss_cls: 0.008842  loss_box_reg: 0.06924  loss_rpn_cls: 0.002197  loss_rpn_loc: 0.002014    time: 1.1407  last_time: 1.1401  data_time: 0.7084  last_data_time: 0.6893   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:28:42 d2.utils.events]:  eta: 0:03:03  iter: 1839  total_loss: 0.08534  loss_cls: 0.01017  loss_box_reg: 0.07535  loss_rpn_cls: 0.00229  loss_rpn_loc: 0.001908    time: 1.1408  last_time: 1.1857  data_time: 0.7078  last_data_time: 0.7330   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:29:05 d2.utils.events]:  eta: 0:02:40  iter: 1859  total_loss: 0.08195  loss_cls: 0.008763  loss_box_reg: 0.06821  loss_rpn_cls: 0.001524  loss_rpn_loc: 0.001939    time: 1.1407  last_time: 1.1078  data_time: 0.7026  last_data_time: 0.6979   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:29:27 d2.utils.events]:  eta: 0:02:17  iter: 1879  total_loss: 0.1351  loss_cls: 0.02484  loss_box_reg: 0.08844  loss_rpn_cls: 0.001964  loss_rpn_loc: 0.002111    time: 1.1406  last_time: 1.2368  data_time: 0.7045  last_data_time: 0.7812   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:29:50 d2.utils.events]:  eta: 0:01:54  iter: 1899  total_loss: 0.1  loss_cls: 0.0133  loss_box_reg: 0.07477  loss_rpn_cls: 0.002416  loss_rpn_loc: 0.002087    time: 1.1403  last_time: 1.1520  data_time: 0.6852  last_data_time: 0.7017   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:30:12 d2.utils.events]:  eta: 0:01:31  iter: 1919  total_loss: 0.09553  loss_cls: 0.01193  loss_box_reg: 0.07211  loss_rpn_cls: 0.002399  loss_rpn_loc: 0.002207    time: 1.1401  last_time: 1.1082  data_time: 0.6985  last_data_time: 0.7106   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:30:35 d2.utils.events]:  eta: 0:01:08  iter: 1939  total_loss: 0.109  loss_cls: 0.01053  loss_box_reg: 0.07665  loss_rpn_cls: 0.001994  loss_rpn_loc: 0.002121    time: 1.1400  last_time: 1.1114  data_time: 0.7009  last_data_time: 0.7001   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:30:57 d2.utils.events]:  eta: 0:00:45  iter: 1959  total_loss: 0.0939  loss_cls: 0.01004  loss_box_reg: 0.0713  loss_rpn_cls: 0.001865  loss_rpn_loc: 0.001999    time: 1.1399  last_time: 1.1059  data_time: 0.7105  last_data_time: 0.6959   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:31:20 d2.utils.events]:  eta: 0:00:22  iter: 1979  total_loss: 0.09143  loss_cls: 0.008756  loss_box_reg: 0.06732  loss_rpn_cls: 0.002808  loss_rpn_loc: 0.002056    time: 1.1398  last_time: 1.1094  data_time: 0.7010  last_data_time: 0.7005   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:31:43 d2.utils.events]:  eta: 0:00:00  iter: 1999  total_loss: 0.08651  loss_cls: 0.007618  loss_box_reg: 0.07118  loss_rpn_cls: 0.002444  loss_rpn_loc: 0.002347    time: 1.1397  last_time: 1.0868  data_time: 0.6966  last_data_time: 0.6897   lr: 6.25e-06  max_mem: 4231M
# [02/10 16:31:43 d2.engine.hooks]: Overall training speed: 1998 iterations in 0:37:57 (1.1397 s / it)
# [02/10 16:31:43 d2.engine.hooks]: Total training time: 0:38:09 (0:00:12 on hooks)
#   0%|          | 0/159 [00:00<?, ?it/s]
# [02/10 16:31:43 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/10 16:31:43 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/10 16:31:43 d2.data.common]: Serializing 8 elements to byte tensors and concatenating them all ...
# [02/10 16:31:43 d2.data.common]: Serialized dataset takes 0.00 MiB
# WARNING [02/10 16:31:43 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
evaluator = COCOEvaluator(Data_Resister_training, cfg, False, output_dir="./output/")
evaluatorIoU = RotatedCOCOEvaluator(Data_Resister_training, cfg, False, output_dir="./output/")
cfg.MODEL.WEIGHTS="./output/model_final.pth"
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set a custom testing threshold
val_loader = build_detection_test_loader(cfg, Data_Resister_training)
inference_on_dataset(trainer.model, val_loader, evaluatorIoU)
# Out:
# WARNING [02/10 16:31:43 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# [02/10 16:31:43 d2.evaluation.coco_evaluation]: Trying to convert 'PL_data_train' to COCO format ...
# [02/10 16:31:43 d2.data.datasets.coco]: Converting annotations of dataset 'PL_data_train' to COCO format ...)
#   0%|          | 0/159 [00:00<?, ?it/s]
# [02/10 16:31:44 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [02/10 16:31:44 d2.data.datasets.coco]: Conversion finished, #images: 151, #annotations: 155
# [02/10 16:31:44 d2.data.datasets.coco]: Caching COCO format annotations at './output/PL_data_train_coco_format.json' ...
# WARNING [02/10 16:31:44 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
#   0%|          | 0/159 [00:00<?, ?it/s]
# [02/10 16:31:44 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/10 16:31:44 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/10 16:31:44 d2.data.common]: Serializing 151 elements to byte tensors and concatenating them all ...
# [02/10 16:31:44 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/10 16:31:44 d2.evaluation.evaluator]: Start inference on 151 batches
# [02/10 16:31:47 d2.evaluation.evaluator]: Inference done 11/151. Dataloading: 0.1459 s/iter. Inference: 0.0670 s/iter. Eval: 0.0003 s/iter. Total: 0.2131 s/iter. ETA=0:00:29
# [02/10 16:31:52 d2.evaluation.evaluator]: Inference done 32/151. Dataloading: 0.1683 s/iter. Inference: 0.0672 s/iter. Eval: 0.0003 s/iter. Total: 0.2358 s/iter. ETA=0:00:28
# [02/10 16:31:57 d2.evaluation.evaluator]: Inference done 53/151. Dataloading: 0.1708 s/iter. Inference: 0.0673 s/iter. Eval: 0.0003 s/iter. Total: 0.2384 s/iter. ETA=0:00:23
# [02/10 16:32:02 d2.evaluation.evaluator]: Inference done 73/151. Dataloading: 0.1744 s/iter. Inference: 0.0674 s/iter. Eval: 0.0003 s/iter. Total: 0.2421 s/iter. ETA=0:00:18
# [02/10 16:32:07 d2.evaluation.evaluator]: Inference done 94/151. Dataloading: 0.1751 s/iter. Inference: 0.0674 s/iter. Eval: 0.0003 s/iter. Total: 0.2428 s/iter. ETA=0:00:13
# [02/10 16:32:12 d2.evaluation.evaluator]: Inference done 115/151. Dataloading: 0.1750 s/iter. Inference: 0.0674 s/iter. Eval: 0.0003 s/iter. Total: 0.2427 s/iter. ETA=0:00:08
# [02/10 16:32:17 d2.evaluation.evaluator]: Inference done 136/151. Dataloading: 0.1748 s/iter. Inference: 0.0673 s/iter. Eval: 0.0003 s/iter. Total: 0.2425 s/iter. ETA=0:00:03
# [02/10 16:32:21 d2.evaluation.evaluator]: Total inference time: 0:00:35.370265 (0.242262 s / iter per device, on 1 devices)
# [02/10 16:32:21 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:09 (0.067326 s / iter per device, on 1 devices)
# [02/10 16:32:21 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/10 16:32:21 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [02/10 16:32:21 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.922
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.922
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.933
# [02/10 16:32:21 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 92.207 | 97.030 | 97.030 |  nan  |  nan  | 92.207 |
# [02/10 16:32:21 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/10 16:32:21 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP      | category   | AP     | category   | AP   |
# |:-----------|:--------|:-----------|:-------|:-----------|:-----|
# | HIC_table  | 100.000 | US_table   | 84.413 | None       | nan  |
# | None       | nan     | None       | nan    | None       | nan  |
# OrderedDict([('bbox',
#               {'AP': 92.206600660066,
#                'AP50': 97.02970297029702,
#                'AP75': 97.02970297029702,
#                'APs': nan,
#                'APm': nan,
#                'APl': 92.206600660066,
#                'AP-HIC_table': 100.0,
#                'AP-US_table': 84.413201320132,
#                'AP-None': nan})])

# %%
import pandas as pd
metrics_df = pd.read_json("./output/metrics.json", orient="records", lines=True)
mdf = metrics_df.sort_values("iteration")
mdf.head(10).T
# Out:
#                                      0            1            2            3  \
# data_time                     0.732125     0.721541     0.703966     0.695421
# eta_seconds                2298.206663  2272.703289  2234.280439  2196.087760
# fast_rcnn/cls_accuracy        0.875000     1.000000     1.000000     1.000000
# fast_rcnn/false_negative      0.000000     0.000000     0.000000     0.000000
# fast_rcnn/fg_cls_accuracy     0.625000     1.000000     1.000000     1.000000
# iteration                    19.000000    39.000000    59.000000    79.000000
# loss_box_reg                  0.640409     0.537535     0.487710     0.415724
# loss_cls                      0.289616     0.072435     0.130125     0.089114
# loss_rpn_cls                  0.012329     0.001868     0.003623     0.004692
# loss_rpn_loc                  0.007229     0.005884     0.005056     0.004041
# lr                            0.002500     0.002500     0.002500     0.002500
# rank_data_time                0.732125     0.721541     0.703966     0.695421
# roi_head/num_bg_samples       3.000000     3.000000     3.000000     3.000000
# roi_head/num_fg_samples       1.000000     1.000000     1.000000     1.000000
# rpn/num_neg_anchors         251.750000   251.750000   252.000000   252.000000
# rpn/num_pos_anchors           4.250000     4.250000     4.000000     4.000000
# time                          1.160710     1.158129     1.134938     1.139229
# total_loss                    1.026145     0.683381     0.601758     0.541249
#
#                                      4            5            6            7  \
# data_time                     0.695319     0.687220     0.703601     0.703116
# eta_seconds                2171.433874  2138.730571  2115.978118  2092.947218
# fast_rcnn/cls_accuracy        1.000000     1.000000     1.000000     1.000000
# fast_rcnn/false_negative      0.000000     0.000000     0.000000     0.000000
# fast_rcnn/fg_cls_accuracy     1.000000     1.000000     1.000000     1.000000
# iteration                    99.000000   119.000000   139.000000   159.000000
# loss_box_reg                  0.384226     0.385946     0.340494     0.364170
# loss_cls                      0.041115     0.055055     0.056613     0.061828
# loss_rpn_cls                  0.005198     0.003121     0.001984     0.003948
# loss_rpn_loc                  0.004272     0.003708     0.003176     0.005084
# lr                            0.002500     0.002500     0.002500     0.002500
# rank_data_time                0.695319     0.687220     0.703601     0.703116
# roi_head/num_bg_samples       3.000000     3.000000     3.000000     3.000000
# roi_head/num_fg_samples       1.000000     1.000000     1.000000     1.000000
# rpn/num_neg_anchors         252.000000   252.000000   252.250000   252.000000
# rpn/num_pos_anchors           4.000000     4.000000     3.750000     4.000000
# time                          1.127857     1.132540     1.132422     1.127788
# total_loss                    0.451576     0.455204     0.408142     0.467378
#
#                                      8            9
# data_time                     0.706452     0.703745
# eta_seconds                2071.173838  2049.670110
# fast_rcnn/cls_accuracy        1.000000     1.000000
# fast_rcnn/false_negative      0.000000     0.000000
# fast_rcnn/fg_cls_accuracy     1.000000     1.000000
# iteration                   179.000000   199.000000
# loss_box_reg                  0.324199     0.350303
# loss_cls                      0.029247     0.048165
# loss_rpn_cls                  0.002706     0.001760
# loss_rpn_loc                  0.003267     0.003408
# lr                            0.002500     0.002500
# rank_data_time                0.706452     0.703745
# roi_head/num_bg_samples       3.000000     3.000000
# roi_head/num_fg_samples       1.000000     1.000000
# rpn/num_neg_anchors         252.125000   252.250000
# rpn/num_pos_anchors           3.875000     3.750000
# time                          1.148313     1.149019
# total_loss                    0.359414     0.411141

# %%
fig, ax = plt.subplots()

mdf1 = mdf[~mdf["total_loss"].isna()]
ax.plot(mdf1["iteration"], mdf1["total_loss"], c="C0", label="train")
if "validation_loss" in mdf.columns:
    mdf2 = mdf[~mdf["validation_loss"].isna()]
    ax.plot(mdf2["iteration"], mdf2["validation_loss"], c="C1", label="validation")

# ax.set_ylim([0, 0.5])
ax.legend()
ax.set_title("Loss curve")
plt.show()

# %%
fig, ax = plt.subplots()

mdf1 = mdf[~mdf["fast_rcnn/cls_accuracy"].isna()]
ax.plot(mdf1["iteration"], mdf1["fast_rcnn/cls_accuracy"], c="C0", label="train")
# ax.set_ylim([0, 0.5])
ax.legend()
ax.set_title("Accuracy curve")
plt.show()

# %%
fig, ax = plt.subplots()

mdf1 = mdf[~mdf["fast_rcnn/cls_accuracy"].isna()]
ax.plot(mdf1["iteration"], mdf1["fast_rcnn/cls_accuracy"], c="C0", label="train")
# ax.set_ylim([0, 0.5])
ax.legend()
ax.set_title("Accuracy curve")
plt.show()

# %%
# !pip install -U layoutparser
# Out:
# Collecting layoutparser
#   Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 73.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from layoutparser) (1.24.4)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from layoutparser) (4.9.0.80)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from layoutparser) (1.11.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from layoutparser) (2.1.4)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from layoutparser) (9.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from layoutparser) (6.0.1)
# Requirement already satisfied: iopath in /opt/conda/lib/python3.10/site-packages (from layoutparser) (0.1.9)
# Collecting pdfplumber (from layoutparser)
#   Downloading pdfplumber-0.10.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: pdf2image in /opt/conda/lib/python3.10/site-packages (from layoutparser) (1.17.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from iopath->layoutparser) (4.66.1)
# Requirement already satisfied: portalocker in /opt/conda/lib/python3.10/site-packages (from iopath->layoutparser) (2.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->layoutparser) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->layoutparser) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->layoutparser) (2023.4)
# Collecting pdfminer.six==20221105 (from pdfplumber->layoutparser)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 90.3 MB/s eta 0:00:00
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser)
#   Downloading pypdfium2-4.27.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20221105->pdfplumber->layoutparser) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20221105->pdfplumber->layoutparser) (41.0.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->layoutparser) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser) (2.21)
# Downloading pdfplumber-0.10.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 2.9 MB/s eta 0:00:00
# Downloading pypdfium2-4.27.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 77.2 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber, layoutparser
# Successfully installed layoutparser-0.3.4 pdfminer.six-20221105 pdfplumber-0.10.3 pypdfium2-4.27.0

# %%
import layoutparser as lp

# %%
model = lp.Detectron2LayoutModel('lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config',
                                 '/kaggle/working/output/model_final.pth',
                                 extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.95],
                                 label_map={0:"HIC_table",1: "US_table", 2: "None", 3: "None", 4:"None", 5:"None"})
#######################################################
#image = cv2.imread('/kaggle/input/compressed-data/doc_smaller_26.jpg')
#plt.imshow(image)
color_map = {
    'text':   'red',
    'title':  'blue',
    'list':   'green',
    'table':  'yellow',
    'figure': 'pink',
}
# Out:
# config.yml?dl=1: 8.19kB [00:01, 7.05kB/s]
# [02/10 16:32:39 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /kaggle/working/output/model_final.pth ...

# %%
import cv2
image = cv2.imread("/kaggle/input/tables-data/doc_img_us_29.jpg")
image = image[..., ::-1]

# %%
image.shape
# Out:
# (1785, 2526, 3)

# %%
layout = model.detect(image) # You need to load the image somewhere else, e.g., image = cv2.imread(...)
lp.draw_box(image, layout)
# Out:
# <PIL.Image.Image image mode=RGB size=2526x1785>

# %%
layout
# Out:
# Layout(_blocks=[TextBlock(block=Rectangle(x_1=36.1791877746582, y_1=343.7441711425781, x_2=1562.50146484375, y_2=1333.3131103515625), text=None, id=None, type=US_table, parent=None, next=None, score=0.9907147884368896)], page_data={})
